# %% [markdown]
# ---
# layout: post
# title: Final Sprint 3
# description: Final Sprint 3
# courses: {csp: {week: 1} }
# comments: true
# sticky_rank: 1
# ---

# %%
def get(self):
            """
            Retrieve all groups.
            """
            # Find all the groups
            groups = Group.query.all()
            # Prepare a JSON list of all the groups, using list comprehension
            json_ready = [group.read() for group in groups]
            # Return a JSON list, converting Python dictionaries to JSON format
            return jsonify(json_ready)

# %% [markdown]
# **def get(self):**
#
# This line starts a function called get, which is used to fetch data when called.
#
# **""" Retrieve all groups. """**
#
# This is a quick note explaining that this function gets all the groups.
#
# **groups = Group.query.all()**
#
# This line asks the database for all the group records and stores them in groups.
#
# **json_ready = [group.read() for group in groups]**
#
# This line converts each group into a dictionary format (using group.read()), then puts all of them into a list called json_ready.
#
# **return jsonify(json_ready)**
#
# This line turns the json_ready list into JSON format so it can be sent back to whoever requested it.

# %%
def delete(self):
            """
            Delete a group.
            """
            # Obtain the request data sent by the RESTful client API
            data = request.get_json()
            # Find the group to delete
            group = Group.query.get(data['id'])
            if group is None:
                return {'message': 'Group not found'}, 404
            # Delete the group object using the Object Relational Mapper (ORM) method defined in the model
            group.delete()
            # Return response to the client in JSON format, converting Python dictionaries to JSON format
            return jsonify({'message': 'Group deleted'})

# %% [markdown]
# **def delete(self):**
#
# This line starts a function called delete, which is used to delete a group when called.
#
# **""" Delete a group. """**
#
# This is a quick note explaining that this function deletes a group.
#
# **data = request.get_json()**
#
# This line gets the data sent by the client (like which group to delete) and stores it in data.
#
# **group = Group.query.get(data['id'])**
#
# This line looks in the database for the group with the specific id from data.
#
# **if group is None:**
#
# This line checks if the group was found in the database.
#
# **return {'message': 'Group not found'}, 404**
#
# If the group wasn’t found, this line sends back a message saying "Group not found" with a 404 error code (meaning “not found”).
#
# **group.delete()**
#
# If the group was found, this line deletes it from the database.
#
# **return jsonify({'message': 'Group deleted'})**
#
# Finally, this line sends a message back to the client, saying "Group deleted," in JSON format.

# %%
def put(self):
            """
            Update a group.
            """
            # Obtain the current user from the token required setting in the global context
            current_user = g.current_user
            # Obtain the request data sent by the RESTful client API
            data = request.get_json()
            # Find the group to update
            group = Group.query.get(data['id'])
            if group is None:
                return {'message': 'Group not found'}, 404
            # Update the group object using the data from the request
            group._name = data['name']
            group._section_id = data['section_id']
            group._moderator_id = data.get('moderator_id', current_user.id)
            # Save the group object using the Object Relational Mapper (ORM) method defined in the model
            group.update()
            # Return response to the client in JSON format, converting Python dictionaries to JSON format
            return jsonify(group.read())

# %% [markdown]
# **def put(self):**
#
# Starts a function to update a group.
#
# **""" Update a group. """**
#
# A note saying this function updates a group.
#
# **current_user = g.current_user**
#
# Gets the user making the request and saves it as current_user.
#
# **data = request.get_json()**
#
# Gets the data from the client (like the group’s new details).
#
# **group = Group.query.get(data['id'])**
#
# Finds the group in the database by using the id from data.
#
# **if group is None:**
#
# Checks if the group was found.
#
# **return {'message': 'Group not found'}, 404**
#
# If not found, sends back "Group not found" with a 404 error code.
#
# **group._name = data['name']**
#
# Sets the group’s name to the new name from data.
#
# **group._section_id = data['section_id']**
#
# Sets the group’s section ID to the new section ID from data.
#
# **group._moderator_id = data.get('moderator_id', current_user.id)**
#
# Sets the group’s moderator ID to either the one in data or, if missing, the current user’s ID.
#
# **group.update()**
#
# Saves the updated group to the database.
#
# **return jsonify(group.read())**
#
# Sends back the updated group’s details in JSON format.

# %% [markdown]
# | **Assignment**                | **Points**    | **Grade** | **Evidence** |
# |-------------------------------|---------------|-----------|--------------|
# | Sprint 1-3 Review Ticket      | 3             |    85%       |      I would likely receive an 85% for my use of tools like VS Code and Postman because I demonstrated a solid understanding of how to utilize these tools effectively throughout the project. I was able to write and debug code in VS Code with confidence, leveraging its features to streamline my workflow and ensure the project’s functionality. Similarly, I used Postman to test APIs and troubleshoot issues, helping to validate the integration of various components. While I used both tools well overall, there were a few moments where I could have explored additional features or optimized my approach for even better efficiency. For example, I could have utilized more advanced debugging features in VS Code or taken better advantage of Postman’s automated testing capabilities. Though my work was generally effective, these small missed opportunities for optimization held me back from achieving a higher score. With a bit more attention to detail and a deeper exploration of these tools’ full capabilities, I could have further improved my contributions.        |
# | Sprint 3 Team Issue(s)/Plan   | 2             |      85%     | I feel that I did a solid job covering the main points and demonstrating a clear understanding of the overall goals. I was able to articulate the core objectives and strategy effectively, which helped set a strong foundation for the project or presentation. However, I recognize that I missed some details and opportunities for improvement that could have enhanced the overall approach. While I captured the big picture well, there were certain smaller aspects that I didn’t fully explore or emphasize, which could have added more depth or clarity. Additionally, although the organization of my work was effective, I see areas where I could refine specific sections to improve the flow and coherence of the presentation. By addressing these details and taking a more thorough approach in certain areas, I believe I could make the plan more comprehensive and impactful.    |
# | Beginning-2-End Contribution  | 2             |     85%      |     I would likely receive an 85% for my Beginning-2-End contribution because I demonstrated strong engagement throughout the process and contributed meaningfully to the overall effort. I stayed involved and committed, offering valuable input and helping to push the project forward. However, I recognize that there were certain finer details or moments where I lacked consistency, which affected the overall polish of my work. While my contributions were solid and effective, there were areas where I could have been more thorough or attentive, especially when it came to smaller elements that could have enhanced the overall quality or impact. For instance, I might have overlooked some key aspects in the planning phase or missed opportunities to refine certain sections in the execution. These gaps in detail or consistency held me back from achieving a higher score. Moving forward, I can improve by focusing more on these subtleties, ensuring a more seamless and complete contribution across all stages of the process.      |
# | N@tM Team Presentation        | 2             |     85%      |       I feel that I made a valuable contribution to the project and presented my part clearly, but looking back, there are definitely areas where I could have done more to enhance the overall outcome. While I was able to communicate my ideas effectively and ensured my segment was well-understood, I recognize that my delivery could have been smoother. There were moments when I might have conveyed my points with more confidence or clarity, which would have made the presentation more engaging and fluid. Additionally, while I actively participated in the project, I see that there were opportunities to improve coordination within our group. At times, we could have been more aligned in terms of timing, transitions, or consistency in messaging. More frequent communication or a better sense of synchronization could have helped make the entire project feel more cohesive. Overall, I demonstrated a solid understanding of the project goals and put in a good amount of effort, but I recognize that with a few adjustments—particularly in my delivery and our team coordination—I could have contributed even more effectively. There’s room for growth, and I’m committed to refining these aspects moving forward.    |
# | Live Review Indi Demo         | 1             |           |              |
# | **Total**                     | 10            |           |              |
#
# | **Skill**                  | **Points**    | **Grade** | **Evidence** |
# |----------------------------|---------------|-----------|--------------|
# | Work Habits (Analytics)    | 1             |     85%      |      My analytics display my skills well, however I should improve by comitting more.        |
# | Evidence of Role in Team   | 1             |      85%     |       I contributed consistently to the team’s work and actively supported our shared goals, ensuring that my responsibilities were completed effectively and on time. I made an effort to help the team stay on track, often assisting others when needed and participating in discussions to move our project forward. However, there were areas where I could have been more proactive, such as taking the initiative to seek additional tasks or suggest improvements. Additionally, I could have been more collaborative, engaging more openly with team members and contributing additional ideas during planning sessions. While I met my core responsibilities well, there’s room to improve my communication, especially in keeping others informed of my progress and seeking feedback more regularly. Enhancing my engagement in these ways could strengthen the overall effectiveness of the team and create an even more collaborative environment.    |
# | Function / Purpose Design  | 1             |    90%       |       I believe I demonstrated a clear understanding of the goals and made sure my work aligned closely with the intended outcomes. I took care to ensure that my approach was focused, targeting the right objectives and staying on track throughout the process. This allowed me to contribute meaningfully and effectively to the overall project. However, looking back, I realize there may have been a few minor areas where I could have refined my approach to fully maximize the impact of my contributions. Whether it was tweaking a particular section for greater clarity, adding more detail where needed, or improving the flow of my work to better connect with the rest of the project, these small adjustments could have enhanced the overall outcome. While my approach was generally effective, I recognize that fine-tuning these details could have made my contribution even stronger and more impactful.   |
# | Live Review                | 2             |           |              |
# | **Total**                  | 5             |           |              |
